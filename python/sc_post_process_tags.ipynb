# %%
from pathlib import Path
import sys
import os
import shutil
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import gsw
from IPython.display import display,Image
from importlib import reload
import netCDF4

import meop
import meop_metadata
import meop_plot_data
import meop_filenames
import meop_postprocess
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 14
#      11 from importlib import reload
#      12 import netCDF4
# ---> 14 import meop
#      15 import meop_metadata
#      16 import meop_plot_data
#
# File /media/disk2/roquet/MEOP_process/python/meop.py:14
#      12 import gsw
#      13 from pathlib import Path
# ---> 14 import cmocean.cm as cmo
#      16 import warnings
#      17 warnings.filterwarnings("ignore", category=RuntimeWarning)
#
# ModuleNotFoundError: No module named 'cmocean'

# %%
reload(meop)
reload(meop_metadata)
reload(meop_postprocess)
# Out:
# <module 'meop_postprocess' from '/media/disk2/roquet/MEOP_process/python/meop_postprocess.py'>

# %%
lprofiles, ltags, ldeployments = meop_metadata.read_lists_metadata(rebuild=True,public=True,Tdata=True,qf='lr1')

# %%
smru_name = 'ct3-9934-04'
ds = meop.open_dataset(meop_filenames.fname_prof(smru_name,qf='lr1'))
lprof = ds.list_metadata()
lprof[(lprof.LATITUDE==0)&(lprof.N_TEMP)]
# Out:
# Empty DataFrame
# Columns: [DEPLOYMENT_CODE, SMRU_PLATFORM_CODE, CYCLE_NUMBER, JULD, LATITUDE, LONGITUDE, N_TEMP, N_PSAL, N_CHLA, year, month, day, MASK]
# Index: []

# %%
meop_plot_data.plot_map_deployments(lprofiles,
                          groupby='MASK',
                          title=f'Distribution of profiles',
                          legend=True,
                          namefig='Global_distribution_by_regions.png',
                          folder=meop_filenames.processdir,
                         )
# Out:
# (<Figure size 1080x1080 with 1 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f58c9783910>)

# %%
meop_postprocess.remove_bad_locations()

# %%
lprofiles, ltags, ldeployments = meop_metadata.read_lists_metadata(public=True,Tdata=True,qf='lr1')
meop_plot_data.plot_map_deployments(lprofiles,
                          groupby='MASK',
                          title=f'Distribution of profiles',
                          legend=True,
                          namefig='Global_distribution_by_regions.png',
                          folder=meop_filenames.processdir,
                         )
# Out:
# (<Figure size 1080x1080 with 1 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f58c6653bd0>)

# %%
smru_name = 'ct3-9934-04'
ds = meop.open_dataset(meop_filenames.fname_prof(smru_name,qf='lr1'))
lprof = ds.list_metadata()
lprof[(lprof.LATITUDE==0)&(lprof.N_TEMP)]
# Out:
# Empty DataFrame
# Columns: [DEPLOYMENT_CODE, SMRU_PLATFORM_CODE, CYCLE_NUMBER, JULD, LATITUDE, LONGITUDE, N_TEMP, N_PSAL, N_CHLA, year, month, day, MASK]
# Index: []
