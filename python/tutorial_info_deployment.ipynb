# %% [markdown]
# # Info and Plots about the deployment

# %%
deployment = 'ct107'
reload(meop_metadata)
lprofiles, ltags, ldeployments = meop_metadata.list_profiles_from_ncfile(qf='lr0',deployment=deployment)

# %%
ltags.head()
# Out:
#   SMRU_PLATFORM_CODE DEPLOYMENT_CODE                        JULD   LATITUDE  \
# 0       ct107-933-13           ct107  2014-02-03 08:20:00.000002  37.192722
# 1      ct107-933b-13           ct107  2014-09-03 23:29:59.999997  43.223513
# 2    ct107-934-13-N1           ct107  2014-02-01 23:29:59.999997  37.416895
# 3    ct107-934-13-N2           ct107  2014-06-16 05:49:59.999996  37.147900
# 4    ct107-938-13-N1           ct107  2014-02-03 23:40:00.000001  37.115500
#
#     LONGITUDE           MASK  N_PROF_TEMP  N_PROF_PSAL  N_PROF_CHLA  PUBLIC  \
# 0 -122.699958  North Pacific          202          202            0       1
# 1 -149.805575  North Pacific            0            0            0       1
# 2 -123.083985  North Pacific          186          186            0       1
# 3 -122.388900  North Pacific           54           54            0       1
# 4 -122.442100  North Pacific          204          204            0       1
#
#    ...    S2  remove  Sremove    comments  variable_offset  instr_id  year  \
# 0  ... -0.03       0        0  no comment              NaN     12933  2014
# 1  ...  0.00       1        0  no comment              NaN       NaN   NaN
# 2  ...  0.06       0        0  no comment              NaN     12934  2014
# 3  ...  0.06       0        0  no comment              NaN       NaN   NaN
# 4  ... -0.02       0        0  no comment              NaN       NaN   NaN
#
#          period continuous   prefix
# 0  reproduction        0.0  2014001
# 1           NaN        NaN      NaN
# 2  reproduction        0.0  2014003
# 3           NaN        NaN      NaN
# 4           NaN        NaN      NaN
#
# [5 rows x 23 columns]

# %%
meop_plot_data.plot_map_deployments(lprofiles)
# Out:
# (<Figure size 720x720 with 1 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f7593124450>)

# %%
meop_plot_data.plot_data_deployments(deployment)
# Out:
# (<Figure size 864x648 with 5 Axes>,
#  {'T': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d7d490>,
#   'S': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d941d0>,
#   'D': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d33590>,
#   'TS': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d4bb10>,
#   'xy': <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f7593d88a50>})
