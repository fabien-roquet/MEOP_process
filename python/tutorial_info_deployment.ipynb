# %% [markdown]
# # Info and Plots about the deployment

# %%
import meop
import meop_plot_data
import meop_metadata
import meop_filenames
from importlib import reload

# %%
deployment = 'ct164'
qf='lr0'
lprofiles, ltags, ldeployments = meop_metadata.list_profiles_from_ncfile(qf='lr0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 deployment = 'ct164'
#       2 qf='lr0'
# ----> 3 lprofiles, ltags, ldeployments = meop_metadata.list_profiles_from_ncfile(qf='lr0')
#
# ValueError: too many values to unpack (expected 3)

# %%
ltags.head()

# %%
meop_plot_data.plot_map_deployments(lprofiles)

# %%
meop_plot_data.plot_data_deployments(deployment)
# Out:
# (<Figure size 864x648 with 5 Axes>,
#  {'T': <matplotlib.axes._subplots.AxesSubplot at 0x7f6b37ba1390>,
#   'S': <matplotlib.axes._subplots.AxesSubplot at 0x7f6b37ac45d0>,
#   'D': <matplotlib.axes._subplots.AxesSubplot at 0x7f6b37a20650>,
#   'TS': <matplotlib.axes._subplots.AxesSubplot at 0x7f6b37a35e90>,
#   'xy': <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f6b37bbf690>})
