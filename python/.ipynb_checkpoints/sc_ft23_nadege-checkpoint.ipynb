# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import meop
from importlib import reload
reload(meop)
# Out:
# <module 'meop' from '/media/disk2/roquet/MEOP_process/python/meop.py'>

# %%
smru_name = 'ft23-C899-18'
namefile = meop.fname_prof(smru_name,qf='lr1')

ds = meop.read_ncfile(namefile)

ds.plot_data_tags('_ADJUSTED')
ds.plot_TSsections('_ADJUSTED',rolling=2)

ds.close()

# %%
smru_name = 'ft23-C900-18'
namefile = meop.fname_prof(smru_name,qf='lr0')

ds = meop.read_ncfile(namefile)

ds.plot_data_tags('_ADJUSTED')
ds.plot_TSsections('_ADJUSTED',rolling=2)

ds.close()

# %%
path_public = '/home/jupyter-froqu/dropbox/PUBLIC/public/MEOP-CTD_2021-05-13'
country = 'FRANCE'
smru_name = 'ft23-C899-18'
qf = 'all'
namefile = f'{path_public}/{country}/DATA/{smru_name}_{qf}_prof.nc'

ds = meop.read_ncfile(namefile)
ds.plot_data_tags('')
ds.plot_TSsections('',rolling=2)
ds.close()

# %%
path_public = '/home/jupyter-froqu/dropbox/PUBLIC/public/MEOP-CTD_2021-05-13'
country = 'FRANCE'
smru_name = 'ft23-C899-18'
qf = 'all'
namefile = f'{path_public}/{country}/DATA/{smru_name}_{qf}_prof.nc'

ds = meop.read_ncfile(namefile)
ds.PRES.std(dim='N_PROF').sum()==0
# Out:
# <xarray.DataArray 'PRES' ()>
# array(False)

# %%
ds.close()
