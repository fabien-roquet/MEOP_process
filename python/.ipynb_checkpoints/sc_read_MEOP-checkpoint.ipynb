# %% [markdown]
# # Script to read MEOP data

# %%
from pathlib import Path
import sys
import os
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import gsw
import meop
import meop_plot_data
import meop_metadata
from importlib import reload

# %% [markdown]
# # Plots about the tag

# %%
deployment = 'ct107'
smru_name = 'ct107-933-13'
qf = 'hr1'
namefile = meop.fname_prof(smru_name,depl,qf)
ds = meop.read_ncfile(namefile)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                       (N_CALIB: 1, N_LEVELS: 1000, N_PARAM: 4, N_PROF: 202)
# Coordinates:
#   * N_CALIB                       (N_CALIB) int64 0
#   * N_LEVELS                      (N_LEVELS) int64 0 1 2 3 4 ... 996 997 998 999
#   * N_PARAM                       (N_PARAM) int64 0 1 2 3
#   * N_PROF                        (N_PROF) int64 0 1 2 3 4 ... 198 199 200 201
# Data variables:
#     DATA_TYPE                     object ...
#     FORMAT_VERSION                object ...
#     HANDBOOK_VERSION              object ...
#     REFERENCE_DATE_TIME           object ...
#     DATE_CREATION                 object ...
#     DATE_UPDATE                   object ...
#     PLATFORM_NUMBER               (N_PROF) object ...
#     PROJECT_NAME                  (N_PROF) object ...
#     PI_NAME                       (N_PROF) object ...
#     STATION_PARAMETERS            (N_PROF, N_PARAM) object ...
#     CYCLE_NUMBER                  (N_PROF) float64 ...
#     DIRECTION                     (N_PROF) object ...
#     DATA_CENTRE                   (N_PROF) object ...
#     DC_REFERENCE                  (N_PROF) object ...
#     DATA_STATE_INDICATOR          (N_PROF) object ...
#     DATA_MODE                     (N_PROF) object ...
#     INST_REFERENCE                (N_PROF) object ...
#     WMO_INST_TYPE                 (N_PROF) object ...
#     JULD                          (N_PROF) object ...
#     JULD_QC                       (N_PROF) object ...
#     JULD_LOCATION                 (N_PROF) object ...
#     LATITUDE                      (N_PROF) float64 ...
#     LONGITUDE                     (N_PROF) float64 ...
#     POSITION_QC                   (N_PROF) object ...
#     POSITIONING_SYSTEM            (N_PROF) object ...
#     PROFILE_PRES_QC               (N_PROF) object ...
#     PROFILE_PSAL_QC               (N_PROF) object ...
#     PROFILE_TEMP_QC               (N_PROF) object ...
#     PRES                          (N_PROF, N_LEVELS) float32 ...
#     PRES_QC                       (N_PROF, N_LEVELS) object ...
#     PRES_ADJUSTED                 (N_PROF, N_LEVELS) float32 ...
#     PRES_ADJUSTED_QC              (N_PROF, N_LEVELS) object ...
#     PRES_ADJUSTED_ERROR           (N_PROF, N_LEVELS) float32 ...
#     TEMP                          (N_PROF, N_LEVELS) float32 ...
#     TEMP_QC                       (N_PROF, N_LEVELS) object ...
#     TEMP_ADJUSTED                 (N_PROF, N_LEVELS) float32 ...
#     TEMP_ADJUSTED_QC              (N_PROF, N_LEVELS) object ...
#     TEMP_ADJUSTED_ERROR           (N_PROF, N_LEVELS) float32 ...
#     PSAL                          (N_PROF, N_LEVELS) float32 ...
#     PSAL_QC                       (N_PROF, N_LEVELS) object ...
#     PSAL_ADJUSTED                 (N_PROF, N_LEVELS) float32 ...
#     PSAL_ADJUSTED_QC              (N_PROF, N_LEVELS) object ...
#     PSAL_ADJUSTED_ERROR           (N_PROF, N_LEVELS) float32 ...
#     PROFILE_CHLA_QC               (N_PROF) object ...
#     CHLA                          (N_PROF, N_LEVELS) float32 ...
#     CHLA_QC                       (N_PROF, N_LEVELS) object ...
#     CHLA_ADJUSTED                 (N_PROF, N_LEVELS) float32 ...
#     CHLA_ADJUSTED_QC              (N_PROF, N_LEVELS) object ...
#     CHLA_ADJUSTED_ERROR           (N_PROF, N_LEVELS) float32 ...
#     PARAMETER                     (N_PROF, N_CALIB, N_PARAM) object ...
#     SCIENTIFIC_CALIB_EQUATION     (N_PROF, N_CALIB, N_PARAM) object ...
#     SCIENTIFIC_CALIB_COEFFICIENT  (N_PROF, N_CALIB, N_PARAM) object ...
# Attributes:
#     comment:
#     number_of_ts_profiles:    202.0
#     number_of_t_profiles:     202.0
#     number_chla_profiles:     0.0
#     number_doxy_profiles:     0.0
#     number_light_profiles:    0.0
#     geospatial_lat_min:       37.19272206978283
#     geospatial_lat_max:       47.72091363130501
#     geospatial_lon_min:       207.59866859208003
#     geospatial_lon_max:       237.30004208675754
#     pi_name:                  COSTA
#     data_type:                Marine mammals time-series data
#     format_version:           1.1
#     date_update:              2020-11-16T13:00:06Z
#     version_database:         MEOP-CTD_2020-10-20
#     PI:                       COSTA
#     reference_file_name:      ct107-933-13_prof.nc
#     is_the_data_public:       yes: data can be used freely providing that dat...
#     nation:                   USA
#     deployment_code:          ct107
#     source:                   Marine mammal observation
#     data_mode:                D
#     references:               http://www.meop.net
#     reference_doi:
#     Conventions:              CF-1.6 Sea-mammals-1.1
#     Netcdf_version:           3.6
#     naming_authority:         MEOP consortium (Marine Mammals Exploring the O...
#     cdm_data_type:            Station
#     geospatial_vertical_min:  0.0
#     geospatial_vertical_max:  2000.0
#     data_assembly_center:     MEOP/Fabien Roquet (MISU)
#     distribution_statement:   Follow MEOP data policy standards, cf. http://w...
#     citation:                 The marine mammal data were collected and made ...
#     thermal_lag_adjustment:   yes
#     platform_code:            44904
#     wmo_platform_code:        Q9900655
#     smru_platform_code:       ct107-933-13
#     species:
#     time_coverage_start:      2014-02-02T00:00:00Z
#     time_coverage_end:        2014-05-01T00:00:00Z
#     location:                 Ano Nuevo.California
#     loc_algorithm:            L
#     firmware_version:         119
#     firmware_parameters:      CTD_GEN_13B
#     instr_id:                 12933
#     ptt:                      133774

# %%
ds.list_metadata()
# Out:
#     DEPLOYMENT_CODE SMRU_PLATFORM_CODE  CYCLE_NUMBER  \
# 0             ct107       ct107-933-13             1
# 1             ct107       ct107-933-13             2
# 2             ct107       ct107-933-13             3
# 3             ct107       ct107-933-13             4
# 4             ct107       ct107-933-13             5
# ..              ...                ...           ...
# 197           ct107       ct107-933-13           198
# 198           ct107       ct107-933-13           199
# 199           ct107       ct107-933-13           200
# 200           ct107       ct107-933-13           201
# 201           ct107       ct107-933-13           202
#
#                            JULD  LATITUDE  LONGITUDE  N_TEMP  N_PSAL  N_CHLA
# 0    2014-02-03 08:20:00.000002   37.1720  -122.7780   514.0   514.0     NaN
# 1    2014-02-03 19:10:00.000001   37.2458  -123.4188   502.0   502.0     NaN
# 2           2014-02-04 18:00:00   37.3050  -124.2974   540.0   540.0     NaN
# 3    2014-02-05 03:10:00.000004   37.3046  -124.6129   484.0   484.0     NaN
# 4    2014-02-05 07:10:00.000001   37.3181  -124.8960   300.0   300.0     NaN
# ..                          ...       ...        ...     ...     ...     ...
# 197  2014-04-18 16:19:59.999996   39.0462  -123.7548    58.0    58.0     NaN
# 198  2014-04-19 01:19:59.999996   38.7037  -124.0214   570.0   570.0     NaN
# 199  2014-04-19 07:19:59.999996   38.4822  -123.8449   500.0   500.0     NaN
# 200         2014-04-20 03:00:00   38.0000  -123.3139   110.0   110.0     NaN
# 201  2014-04-20 09:59:59.999997   37.7038  -122.8913    50.0    50.0     NaN
#
# [202 rows x 9 columns]

# %%
ds.plot_map()
# Out:
# (<Figure size 720x720 with 1 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f7599963550>)

# %%
ds.plot_data_tags()
# Out:
# (<Figure size 864x648 with 5 Axes>,
#  {'T': <matplotlib.axes._subplots.AxesSubplot at 0x7f759819eb90>,
#   'S': <matplotlib.axes._subplots.AxesSubplot at 0x7f7598172790>,
#   'D': <matplotlib.axes._subplots.AxesSubplot at 0x7f758bd08cd0>,
#   'TS': <matplotlib.axes._subplots.AxesSubplot at 0x7f758e0cf050>,
#   'xy': <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f758bd13cd0>})

# %%
ds.plot_profiles(['TEMP','PSAL','SIG0'])
# Out:
# (<Figure size 720x720 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f758e8e4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758e8b5c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758e910f50>],
#        dtype=object))

# %%
ds.plot_TSsections()

# %% [markdown]
# # select a subset of profiles

# %%
ds.isel({'N_PROF':[1,3,10]}).plot_data_tags()
# Out:
# (<Figure size 864x648 with 5 Axes>,
#  {'T': <matplotlib.axes._subplots.AxesSubplot at 0x7f758de8ae90>,
#   'S': <matplotlib.axes._subplots.AxesSubplot at 0x7f758bcac690>,
#   'D': <matplotlib.axes._subplots.AxesSubplot at 0x7f758e849250>,
#   'TS': <matplotlib.axes._subplots.AxesSubplot at 0x7f758e50fcd0>,
#   'xy': <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f758e0c9f50>})

# %%
ds.isel({'N_PROF':ds.LONGITUDE>-125}).plot_data_tags()
# Out:
# (<Figure size 864x648 with 5 Axes>,
#  {'T': <matplotlib.axes._subplots.AxesSubplot at 0x7f7579eb0190>,
#   'S': <matplotlib.axes._subplots.AxesSubplot at 0x7f7579d14e90>,
#   'D': <matplotlib.axes._subplots.AxesSubplot at 0x7f7579d51450>,
#   'TS': <matplotlib.axes._subplots.AxesSubplot at 0x7f7579c439d0>,
#   'xy': <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f7579ea7c10>})

# %% [markdown]
# # Info and Plots about the deployment

# %%
deployment = 'ct107'
reload(meop_metadata)
lprofiles, ltags, ldeployments = meop_metadata.list_profiles_from_ncfile(qf='lr0',deployment=deployment)

# %%
ltags.head()
# Out:
#   SMRU_PLATFORM_CODE DEPLOYMENT_CODE                        JULD   LATITUDE  \
# 0       ct107-933-13           ct107  2014-02-03 08:20:00.000002  37.192722
# 1      ct107-933b-13           ct107  2014-09-03 23:29:59.999997  43.223513
# 2    ct107-934-13-N1           ct107  2014-02-01 23:29:59.999997  37.416895
# 3    ct107-934-13-N2           ct107  2014-06-16 05:49:59.999996  37.147900
# 4    ct107-938-13-N1           ct107  2014-02-03 23:40:00.000001  37.115500
#
#     LONGITUDE           MASK  N_PROF_TEMP  N_PROF_PSAL  N_PROF_CHLA  PUBLIC  \
# 0 -122.699958  North Pacific          202          202            0       1
# 1 -149.805575  North Pacific            0            0            0       1
# 2 -123.083985  North Pacific          186          186            0       1
# 3 -122.388900  North Pacific           54           54            0       1
# 4 -122.442100  North Pacific          204          204            0       1
#
#    ...    S2  remove  Sremove    comments  variable_offset  instr_id  year  \
# 0  ... -0.03       0        0  no comment              NaN     12933  2014
# 1  ...  0.00       1        0  no comment              NaN       NaN   NaN
# 2  ...  0.06       0        0  no comment              NaN     12934  2014
# 3  ...  0.06       0        0  no comment              NaN       NaN   NaN
# 4  ... -0.02       0        0  no comment              NaN       NaN   NaN
#
#          period continuous   prefix
# 0  reproduction        0.0  2014001
# 1           NaN        NaN      NaN
# 2  reproduction        0.0  2014003
# 3           NaN        NaN      NaN
# 4           NaN        NaN      NaN
#
# [5 rows x 23 columns]

# %%
meop_plot_data.plot_map_deployments(lprofiles)
# Out:
# (<Figure size 720x720 with 1 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f7593124450>)

# %%
meop_plot_data.plot_data_deployments(deployment)
# Out:
# (<Figure size 864x648 with 5 Axes>,
#  {'T': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d7d490>,
#   'S': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d941d0>,
#   'D': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d33590>,
#   'TS': <matplotlib.axes._subplots.AxesSubplot at 0x7f7593d4bb10>,
#   'xy': <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f7593d88a50>})
