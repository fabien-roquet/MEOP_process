# %%
import meop_process
from pathlib import Path
import sys
import os
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
import gsw
import cartopy.crs as ccrs

from importlib import reload
import meop
import meop_metadata
import meop_plot_data

# %%
reload(meop)
reload(meop_metadata)
reload(meop_process)
reload(meop_plot_data)
# Out:
# <module 'meop_plot_data' from '/media/disk2/roquet/MEOP_process/python/meop_plot_data.py'>

# %%
smru_name='ct107-933-13'
fname_all = meop.fname_prof(smru_name,qf='all')

# %%
meop_process.create_final_ncfile(smru_name)
# Out:
# copy: ct107-933-13_lr1_prof.nc
# PosixPath('/home/jupyter-froqu/MEOP_process/final_dataset_prof/ct107/ct107-933-13_all_prof.nc')

# %%
ds = meop.read_ncfile(fname_all)

# %%
ds.plot_profiles('TEMP')
# Out:
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc343d21650>)

# %%
ds.sel({'N_PROF':[1]})
# Out:
# <xarray.Dataset>
# Dimensions:                       (N_CALIB: 1, N_LEVELS: 1000, N_PARAM: 4, N_PROF: 1)
# Coordinates:
#   * N_CALIB                       (N_CALIB) int64 0
#   * N_LEVELS                      (N_LEVELS) int64 0 1 2 3 4 ... 996 997 998 999
#   * N_PARAM                       (N_PARAM) int64 0 1 2 3
#   * N_PROF                        (N_PROF) int64 1
# Data variables:
#     DATA_TYPE                     object b'Argo profile    '
#     FORMAT_VERSION                object b'3.0 '
#     HANDBOOK_VERSION              object b'3.0 '
#     REFERENCE_DATE_TIME           object b'19500101000000'
#     DATE_CREATION                 object b'20201116125818'
#     DATE_UPDATE                   object b'20201116125818'
#     PLATFORM_NUMBER               (N_PROF) object b'00044904'
#     PROJECT_NAME                  (N_PROF) object b'                         ...
#     PI_NAME                       (N_PROF) object b'                         ...
# ...
